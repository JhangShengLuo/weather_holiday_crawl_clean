# %%
import pandas as pd
import re
import time
import matplotlib.pyplot as plt
import numpy as np
import requests
from bs4 import BeautifulSoup as bs
from datetime import datetime, timedelta
from itertools import repeat
# %matplotlib inline

# %%
"""# 算出總共要幾天
from datetime import datetime, timedelta
start = datetime(2017, 5, 28)
end = datetime(2014, 4, 1)
print (start - end)"""

# %%
from datetime import datetime, timedelta
start=datetime(2017, 5, 28)
appdf = pd.DataFrame()
for i in range(1,1166):
    time.sleep(1)
    dt = start - timedelta(days = i)
    mytime = dt.strftime('%Y-%m-%d')
    url="http://e-service.cwb.gov.tw/HistoryDataQuery/DayDataController.do?command=viewMain&station=C0AC70&stname=%25E4%25BF%25A1%25E7%25BE%25A9&datepicker={}".format(mytime)
    res = requests.post(url)
    res.encoding = "utf-8"
    soup = bs(res.text,'lxml')
    tb=soup.select("div.CSSTableGenerator #MyTable")

    dfs = pd.read_html(tb[0].prettify('utf-8'), encoding='utf-8')
    yet_clean=dfs[0].copy()
    yet_clean=yet_clean.drop([0],axis=0).reset_index(drop=True)
    new_col=["ObsTime","StnPres","SeaPres","Temperature","point","RH"\
             ,"WS","WD","WSGust","WDGust","Precp","PrecpHour","SunShine","GloblRad","Visb"]
    yet_clean.columns = new_col
    yet_clean=yet_clean.drop([0],axis=0).reset_index(drop=True)
    yet_clean.insert(0,"to_date",mytime)
    appdf=appdf.append(yet_clean)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-254dc2df6bbe> in <module>()
#       7     mytime = dt.strftime('%Y-%m-%d')
#       8     url="http://e-service.cwb.gov.tw/HistoryDataQuery/DayDataController.do?command=viewMain&station=C0AC70&stname=%25E4%25BF%25A1%25E7%25BE%25A9&datepicker={}".format(mytime)
# ----> 9     res = requests.post(url)
#      10     res.encoding = "utf-8"
#      11     soup = bs(res.text,'lxml')
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/requests/api.py in post(url, data, json, **kwargs)
#     110     """
#     111
# --> 112     return request('post', url, data=data, json=json, **kwargs)
#     113
#     114
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     511         }
#     512         send_kwargs.update(settings)
# --> 513         resp = self.send(prep, **send_kwargs)
#     514
#     515         return resp
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     661
#     662         if not stream:
# --> 663             r.content
#     664
#     665         return r
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/requests/models.py in content(self)
#     815                 self._content = None
#     816             else:
# --> 817                 self._content = bytes().join(self.iter_content(CONTENT_CHUNK_SIZE)) or bytes()
#     818
#     819         self._content_consumed = True
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/requests/models.py in generate()
#     737             if hasattr(self.raw, 'stream'):
#     738                 try:
# --> 739                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     740                         yield chunk
#     741                 except ProtocolError as e:
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     430         """
#     431         if self.chunked and self.supports_chunked_reads():
# --> 432             for line in self.read_chunked(amt, decode_content=decode_content):
#     433                 yield line
#     434         else:
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     595                 if self.chunk_left == 0:
#     596                     break
# --> 597                 chunk = self._handle_chunk(amt)
#     598                 decoded = self._decode(chunk, decode_content=decode_content,
#     599                                        flush_decoder=False)
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/urllib3/response.py in _handle_chunk(self, amt)
#     560             returned_chunk = value
#     561         else:  # amt > self.chunk_left
# --> 562             returned_chunk = self._fp._safe_read(self.chunk_left)
#     563             self._fp._safe_read(2)  # Toss the CRLF at the end of the chunk.
#     564             self.chunk_left = None
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/http/client.py in _safe_read(self, amt)
#     605         s = []
#     606         while amt > 0:
# --> 607             chunk = self.fp.read(min(amt, MAXAMOUNT))
#     608             if not chunk:
#     609                 raise IncompleteRead(b''.join(s), amt)
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/socket.py in readinto(self, b)
#     574         while True:
#     575             try:
# --> 576                 return self._sock.recv_into(b)
#     577             except timeout:
#     578                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
appdf
# Out:
#        to_date ObsTime StnPres SeaPres Temperature point  RH   WS   WD WSGust  \
# 0   2017-05-27       1  1002.8     NaN        22.9   NaN  75  0.8   72    NaN
# 1   2017-05-27       2  1002.1     NaN        23.2   NaN  72  0.6   90    NaN
# 2   2017-05-27       3  1001.8     NaN        23.1   NaN  73  0.6   78    NaN
# 3   2017-05-27       4  1001.6     NaN        23.2   NaN  71  0.5   55    NaN
# 4   2017-05-27       5  1001.6     NaN        23.2   NaN  69  1.1   67    NaN
# 5   2017-05-27       6  1001.9     NaN        23.4   NaN  68  0.5   92    NaN
# 6   2017-05-27       7  1002.1     NaN        23.8   NaN  67  0.9   62    NaN
# 7   2017-05-27       8  1002.6     NaN        24.7   NaN  62  0.6   83    NaN
# 8   2017-05-27       9  1003.2     NaN        25.2   NaN  60  1.2   74    NaN
# 9   2017-05-27      10  1003.7     NaN        24.7   NaN  63  1.0   93    NaN
# 10  2017-05-27      11  1003.8     NaN        24.7   NaN  64  0.8   79    NaN
# 11  2017-05-27      12  1003.9     NaN        24.4   NaN  67  0.4   99    NaN
# 12  2017-05-27      13  1003.9     NaN        22.3   NaN  82  0.7   82    NaN
# 13  2017-05-27      14  1004.1     NaN        20.2   NaN  87  0.8   73    NaN
# 14  2017-05-27      15  1003.8     NaN        19.6   NaN  89  1.1   82    NaN
# 15  2017-05-27      16  1003.6     NaN        19.3   NaN  91  1.1   62    NaN
# 16  2017-05-27      17  1003.6     NaN        19.6   NaN  90  1.0   58    NaN
# 17  2017-05-27      18  1003.1     NaN        19.3   NaN  89  1.0   85    NaN
# 18  2017-05-27      19  1003.2     NaN        19.5   NaN  87  0.8  111    NaN
# 19  2017-05-27      20  1003.2     NaN        19.7   NaN  85  0.7  113    NaN
# 20  2017-05-27      21  1003.3     NaN        19.9   NaN  84  0.7  124    NaN
# 21  2017-05-27      22  1003.1     NaN        20.1   NaN  82  1.0   70    NaN
# 22  2017-05-27      23  1002.9     NaN        20.6   NaN  80  0.6   81    NaN
# 23  2017-05-27      24  1002.4     NaN        20.9   NaN  82  0.8  115    NaN
# 0   2017-05-26       1  1002.3     NaN        22.0   NaN  84  0.0    0    NaN
# 1   2017-05-26       2  1001.8     NaN        22.1   NaN  81  0.0    0    NaN
# 2   2017-05-26       3  1001.5     NaN        22.1   NaN  79  0.1    0    NaN
# 3   2017-05-26       4  1001.5     NaN        22.1   NaN  73  0.2    0    NaN
# 4   2017-05-26       5  1001.5     NaN        22.1   NaN  67  0.1    0    NaN
# 5   2017-05-26       6  1001.9     NaN        22.2   NaN  66  0.0    0    NaN
# ..         ...     ...     ...     ...         ...   ...  ..  ...  ...    ...
# 18  2016-07-25      19  1000.7     NaN        29.9   NaN  71  0.3   23    NaN
# 19  2016-07-25      20  1000.9     NaN        29.4   NaN  68  0.0    0    NaN
# 20  2016-07-25      21  1001.4     NaN        29.1   NaN  68  0.6   49    NaN
# 21  2016-07-25      22  1001.2     NaN        28.7   NaN  69  0.2    0    NaN
# 22  2016-07-25      23  1000.8     NaN        28.7   NaN  69  0.3   96    NaN
# 23  2016-07-25      24  1000.7     NaN        28.6   NaN  68  0.1    0    NaN
# 0   2016-07-24       1  1000.7     NaN        28.5   NaN  72  0.0    0    NaN
# 1   2016-07-24       2  1000.4     NaN        28.0   NaN  78  0.0    0    NaN
# 2   2016-07-24       3  1000.3     NaN        27.6   NaN  79  0.0    0    NaN
# 3   2016-07-24       4  1000.3     NaN        27.6   NaN  80  0.0    0    NaN
# 4   2016-07-24       5  1000.6     NaN        27.3   NaN  80  0.0    0    NaN
# 5   2016-07-24       6  1001.4     NaN        27.2   NaN  80  0.0    0    NaN
# 6   2016-07-24       7  1002.0     NaN        27.6   NaN  79  0.0    0    NaN
# 7   2016-07-24       8  1002.4     NaN        29.7   NaN  71  0.0    0    NaN
# 8   2016-07-24       9  1002.2     NaN        31.5   NaN  65  0.0    0    NaN
# 9   2016-07-24      10  1001.8     NaN        34.0   NaN  58  0.2    0    NaN
# 10  2016-07-24      11  1001.7     NaN        32.9   NaN  58  0.1    0    NaN
# 11  2016-07-24      12  1001.3     NaN        34.0   NaN  57  0.6   30    NaN
# 12  2016-07-24      13  1000.9     NaN        32.3   NaN  63  0.1    0    NaN
# 13  2016-07-24      14  1000.8     NaN        31.6   NaN  67  0.0    0    NaN
# 14  2016-07-24      15  1000.7     NaN        31.9   NaN  64  0.3  142    NaN
# 15  2016-07-24      16  1000.4     NaN        32.1   NaN  62  0.2    0    NaN
# 16  2016-07-24      17  1000.2     NaN        31.1   NaN  64  0.3   73    NaN
# 17  2016-07-24      18  1000.1     NaN        30.5   NaN  62  0.1    0    NaN
# 18  2016-07-24      19  1000.6     NaN        29.7   NaN  70  0.1    0    NaN
# 19  2016-07-24      20  1001.0     NaN        28.6   NaN  81  0.2    0    NaN
# 20  2016-07-24      21  1001.4     NaN        28.0   NaN  83  0.6   64    NaN
# 21  2016-07-24      22  1001.5     NaN        27.9   NaN  78  0.2    0    NaN
# 22  2016-07-24      23  1001.1     NaN        27.8   NaN  73  0.2    0    NaN
# 23  2016-07-24      24  1000.8     NaN        27.4   NaN  74  0.1    0    NaN
#
#    WDGust Precp PrecpHour SunShine GloblRad Visb
# 0     NaN   0.0       NaN      NaN      NaN  NaN
# 1     NaN   0.0       NaN      NaN      NaN  NaN
# 2     NaN   0.0       NaN      NaN      NaN  NaN
# 3     NaN   0.0       NaN      NaN      NaN  NaN
# 4     NaN   0.0       NaN      NaN      NaN  NaN
# 5     NaN   0.0       NaN      NaN      NaN  NaN
# 6     NaN   0.0       NaN      NaN      NaN  NaN
# 7     NaN   0.0       NaN      NaN      NaN  NaN
# 8     NaN   0.0       NaN      NaN      NaN  NaN
# 9     NaN   0.0       NaN      NaN      NaN  NaN
# 10    NaN   0.0       NaN      NaN      NaN  NaN
# 11    NaN   0.0       NaN      NaN      NaN  NaN
# 12    NaN   1.0       NaN      NaN      NaN  NaN
# 13    NaN   4.0       NaN      NaN      NaN  NaN
# 14    NaN   1.5       NaN      NaN      NaN  NaN
# 15    NaN   1.0       NaN      NaN      NaN  NaN
# 16    NaN   0.0       NaN      NaN      NaN  NaN
# 17    NaN   0.0       NaN      NaN      NaN  NaN
# 18    NaN     X       NaN      NaN      NaN  NaN
# 19    NaN   0.0       NaN      NaN      NaN  NaN
# 20    NaN   0.0       NaN      NaN      NaN  NaN
# 21    NaN   0.0       NaN      NaN      NaN  NaN
# 22    NaN   0.0       NaN      NaN      NaN  NaN
# 23    NaN   0.0       NaN      NaN      NaN  NaN
# 0     NaN   0.0       NaN      NaN      NaN  NaN
# 1     NaN   0.0       NaN      NaN      NaN  NaN
# 2     NaN   0.0       NaN      NaN      NaN  NaN
# 3     NaN   0.0       NaN      NaN      NaN  NaN
# 4     NaN   0.0       NaN      NaN      NaN  NaN
# 5     NaN   0.0       NaN      NaN      NaN  NaN
# ..    ...   ...       ...      ...      ...  ...
# 18    NaN   0.0       NaN      NaN      NaN  NaN
# 19    NaN   0.0       NaN      NaN      NaN  NaN
# 20    NaN   0.0       NaN      NaN      NaN  NaN
# 21    NaN   0.0       NaN      NaN      NaN  NaN
# 22    NaN   0.0       NaN      NaN      NaN  NaN
# 23    NaN   0.0       NaN      NaN      NaN  NaN
# 0     NaN   0.0       NaN      NaN      NaN  NaN
# 1     NaN   0.0       NaN      NaN      NaN  NaN
# 2     NaN   0.0       NaN      NaN      NaN  NaN
# 3     NaN   0.0       NaN      NaN      NaN  NaN
# 4     NaN   0.0       NaN      NaN      NaN  NaN
# 5     NaN   0.0       NaN      NaN      NaN  NaN
# 6     NaN   0.0       NaN      NaN      NaN  NaN
# 7     NaN   0.0       NaN      NaN      NaN  NaN
# 8     NaN   0.0       NaN      NaN      NaN  NaN
# 9     NaN   0.0       NaN      NaN      NaN  NaN
# 10    NaN   0.0       NaN      NaN      NaN  NaN
# 11    NaN   0.0       NaN      NaN      NaN  NaN
# 12    NaN   0.0       NaN      NaN      NaN  NaN
# 13    NaN   0.0       NaN      NaN      NaN  NaN
# 14    NaN   0.0       NaN      NaN      NaN  NaN
# 15    NaN   0.0       NaN      NaN      NaN  NaN
# 16    NaN   0.0       NaN      NaN      NaN  NaN
# 17    NaN   0.0       NaN      NaN      NaN  NaN
# 18    NaN   0.0       NaN      NaN      NaN  NaN
# 19    NaN     X       NaN      NaN      NaN  NaN
# 20    NaN   0.0       NaN      NaN      NaN  NaN
# 21    NaN   0.0       NaN      NaN      NaN  NaN
# 22    NaN   0.0       NaN      NaN      NaN  NaN
# 23    NaN   0.0       NaN      NaN      NaN  NaN
#
# [7392 rows x 16 columns]

# %%
appdf=appdf.dropna(how="all",axis=1)

# %%
time_dict={}
for i in range(1,25):
    if len(str(i)) == 1:
        time_dict[str(i)] = "0"+str(i-1)+":00:00"
    elif i==10:
        time_dict[str(i)] = "0"+str(i-1)+":00:00"
    else:
        time_dict[str(i)] = str(i-1)+":00:00"

# %%
pattern={"ObsTime":time_dict}
appdf=appdf.replace(pattern)

# %%
appdf = appdf.reset_index(drop=True)

# %%
appdf.insert(0,"date_time",appdf.to_date+" "+appdf.ObsTime)

# %%
appdf=appdf.drop(["to_date","ObsTime"],axis=1)

# %%
appdf.to_csv("weather_file.csv",index=False,encoding="utf-8")

# %%
wdf = pd.read_csv("weather_file.csv",encoding="utf-8")

pattern={"Precp":{"X":"0","0.0":"0","0\.[123456789]":"1","^[123456789]\d?\.\d":"1"}}
wdfr = wdf.replace(pattern,regex=True)

wdfr.Precp.unique()
# Out:
# array([u'0', u'1'], dtype=object)

# %%
re.findall("^[123456789]\d?\.\d","20.50")
# Out:
# ['20.5']

# %%
wdfr.ix[:,[0,6]].to_csv("rain_or_not_xinyi.csv",index=False,encoding="utf-8")
